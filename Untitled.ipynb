# %%
import pandas as pd
import numpy as np

# %%
jumia_fashion = pd.read_csv('jumia_fashion.csv')
jumia_fashion
# Out:
#                                                   Image  \
# 0     https://ke.jumia.is/unsafe/fit-in/300x300/filt...
# 1     https://ke.jumia.is/unsafe/fit-in/300x300/filt...
# 2     https://ke.jumia.is/unsafe/fit-in/300x300/filt...
# 3     https://ke.jumia.is/unsafe/fit-in/300x300/filt...
# 4     https://ke.jumia.is/unsafe/fit-in/300x300/filt...
# ...                                                 ...
# 1921  https://ke.jumia.is/unsafe/fit-in/300x300/filt...
# 1922  https://ke.jumia.is/unsafe/fit-in/300x300/filt...
# 1923  https://ke.jumia.is/unsafe/fit-in/300x300/filt...
# 1924  https://ke.jumia.is/unsafe/fit-in/300x300/filt...
# 1925  https://ke.jumia.is/unsafe/fit-in/300x300/filt...
#
#                                            Product_Name  \
# 0     Waanzilish Ladies Sneakers Shoes Women's Breat...
# 1                      Fashion Mens Fabric Shoes -Black
# 2     Fashion Mens Leather Shoes Men's Office Leathe...
# 3          Fashion Men's Low Laced Sneakers 04-08-Black
# 4     Fashion Men's Casual Slip On Loafers Low Top C...
# ...                                                 ...
# 1921            Generic Fashion Wrist Band Ladies Watch
# 1922  Fashion International Import Bracelet Elegant ...
# 1923  Fashion Casual Slim Plain Mens Solid Skinny Ne...
# 1924                  Fashion 2 PIECE AFRICAN BABY SUIT
# 1925  Fashion SOFT LADIES BLACK BIKER SHORTS/boy/yog...
#
#                       Price                                               Link
# 0         KSh 750 - KSh 800  /waanzilish-ladies-sneakers-shoes-womens-breat...
# 1                   KSh 945     /fashion-mens-fabric-shoes-black-61923715.html
# 2                   KSh 949  /fashion-mens-leather-shoes-mens-office-leathe...
# 3         KSh 527 - KSh 599  /fashion-mens-low-laced-sneakers-04-08-black-5...
# 4         KSh 861 - KSh 990  /fashion-mens-casual-slip-on-loafers-low-top-c...
# ...                     ...                                                ...
# 1921                KSh 849  /generic-fashion-wrist-band-ladies-watch-58676...
# 1922                KSh 238  /fashion-international-import-bracelet-elegant...
# 1923                KSh 359  /fashion-casual-slim-plain-mens-solid-skinny-n...
# 1924  KSh 2,300 - KSh 2,850   /fashion-2-piece-african-baby-suit-61926186.html
# 1925                KSh 750  /fashion-soft-ladies-black-biker-shortsboyyoga...
#
# [1926 rows x 4 columns]

# %%
def searchFashion():
    jumia_fashion = pd.read_csv('jumia_fashion.csv')
    available_product = {
    'image' : [],
    'product' : [],
    'price' : [],
    'link' : []
}
    #Prompt user search. 
    userInput = input('Enter product')
    
    product_name = jumia_fashion['Product_Name']
    
    # search through the database
    for product in product_name:
        if userInput in product:
#             print(jumia_fashion[jumia_fashion['Product_Name']==product])
            available_product['image'].append(jumia_fashion[jumia_fashion['Product_Name']==product]['Image'])
            available_product['product'].append(jumia_fashion[jumia_fashion['Product_Name']==product]['Product_Name'])
            available_product['price'].append(jumia_fashion[jumia_fashion['Product_Name']==product]['Price'])
            available_product['link'].append(jumia_fashion[jumia_fashion['Product_Name']==product]['Link'])
        

    #display result
    
    if len(available_product)==0:
        display = "Sorry! Out of stock"
        
    else:
        display = {
            'image' : [],
            'product' : [],
            'price' : [],
            'link' : []
        }

#         display = np.zeros((len(available_product),4))
        
        for i in range(len(available_product)):
            display['image'].append(available_product['image'][0].item())#image
            display['product'].append(available_product['product'][0].item())#product
            display['price'].append(available_product['price'][0].item())#price
            display['link'].append(available_product['link'][0].item())#link
            
    return pd.DataFrame(display)
    
searchproduct()
# Out:
# Enter productshoes
#                                                image  \
# 0  https://ke.jumia.is/unsafe/fit-in/300x300/filt...
# 1  https://ke.jumia.is/unsafe/fit-in/300x300/filt...
# 2  https://ke.jumia.is/unsafe/fit-in/300x300/filt...
# 3  https://ke.jumia.is/unsafe/fit-in/300x300/filt...
#
#                        product      price  \
# 0  Generic Unisex Canvas shoes  KSh 1,500
# 1  Generic Unisex Canvas shoes  KSh 1,500
# 2  Generic Unisex Canvas shoes  KSh 1,500
# 3  Generic Unisex Canvas shoes  KSh 1,500
#
#                                          link
# 0  /generic-unisex-canvas-shoes-27225789.html
# 1  /generic-unisex-canvas-shoes-27225789.html
# 2  /generic-unisex-canvas-shoes-27225789.html
# 3  /generic-unisex-canvas-shoes-27225789.html

# %%
A = np.array((2,4),shape=(3,3))

A.shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_125132/2198460352.py in <module>
# ----> 1 A = np.array((2,4),shape=(3,3))
#       2
#       3 A.shape
#
# TypeError: 'shape' is an invalid keyword argument for array()

# %%
product_name = list(jumia_fashion['Product_Name'])
user = 'shoes'

available_product = {
    'image' : [],
    'product' : [],
    'price' : [],
    'link' : []
}
for product in product_name:
    if user in product:
        print(jumia_fashion[jumia_fashion['Product_Name']==product])
        available_product['image'].append(jumia_fashion[jumia_fashion['Product_Name']==product]['Image'])
        available_product['product'].append(jumia_fashion[jumia_fashion['Product_Name']==product]['Product_Name'])
        available_product['price'].append(jumia_fashion[jumia_fashion['Product_Name']==product]['Price'])
        available_product['link'].append(jumia_fashion[jumia_fashion['Product_Name']==product]['Link'])
        
        
        print(type(jumia_fashion[jumia_fashion['Product_Name']==product]['Image']))
#     return
# Out:
#                                                  Image  \
# 908  https://ke.jumia.is/unsafe/fit-in/300x300/filt...
#
#                     Product_Name      Price  \
# 908  Generic Unisex Canvas shoes  KSh 1,500
#
#                                            Link
# 908  /generic-unisex-canvas-shoes-27225789.html
# <class 'pandas.core.series.Series'>
#                                                   Image  \
# 1521  https://ke.jumia.is/unsafe/fit-in/300x300/filt...
#
#                                            Product_Name      Price  \
# 1521  fashion Men's Loafers Handmade Moccasins  Leat...  KSh 5,560
#
#                                                    Link
# 1521  /camel-fashion-mens-loafers-handmade-moccasins...
# <class 'pandas.core.series.Series'>

# %%
for i in range(len(available_product['image'])):
    print(available_product['image'][i].item())

available_product['image'][0].item()
# Out:
# https://ke.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/98/752272/1.jpg?1446
# https://ke.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/32/589601/1.jpg?7582
# 'https://ke.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/98/752272/1.jpg?1446'

# %%
jumia_phones = pd.read_csv('jumia_phones.csv')
jumia_phones
# Out:
#                                                   Image  \
# 0     https://ke.jumia.is/unsafe/fit-in/300x300/filt...
# 1     https://ke.jumia.is/unsafe/fit-in/300x300/filt...
# 2     https://ke.jumia.is/unsafe/fit-in/300x300/filt...
# 3     https://ke.jumia.is/unsafe/fit-in/300x300/filt...
# 4     https://ke.jumia.is/unsafe/fit-in/300x300/filt...
# ...                                                 ...
# 1921  https://ke.jumia.is/unsafe/fit-in/300x300/filt...
# 1922  https://ke.jumia.is/unsafe/fit-in/300x300/filt...
# 1923  https://ke.jumia.is/unsafe/fit-in/300x300/filt...
# 1924  https://ke.jumia.is/unsafe/fit-in/300x300/filt...
# 1925  https://ke.jumia.is/unsafe/fit-in/300x300/filt...
#
#                                            Product_Name       Price  \
# 0     Iworld Fast Charging 3.1A, 1.2m Type C Cable (...     KSh 200
# 1     Samsung Galaxy A03 Core, 6.5" 32GB + 2G, 5000m...  KSh 12,027
# 2     Oppo A83 64GB+4GB RAM - 4G LTE Dual SIM - 5.7-...   KSh 9,299
# 3     XIAOMI  Redmi 9A 6.53" 2GB + 32GB ( Dual Sim) ...  KSh 10,998
# 4     Nokia 105 (2019) 1.77" (Dual SIM) FM Radio,4MB...   KSh 1,460
# ...                                                 ...         ...
# 1921                  Oraimo Fast Android Cable Charger     KSh 190
# 1922   Generic Clear View  Case For Samsung Galaxy  A51   KSh 1,999
# 1923  Generic Mini Wireless Bluetooth 4.0 Stereo In-...     KSh 195
# 1924       Generic Sliding Camshield Case For Nokia C30     KSh 430
# 1925  Generic 4G Kids Smart Watch Global Positioning...   KSh 6,180
#
#                                                    Link
# 0     /iworld-fast-charging-3.1a-1.2m-type-c-cable-c...
# 1     /samsung-galaxy-a03-core-6.5-32gb-2g-5000mahdu...
# 2     /oppo-a83-64gb4gb-ram-4g-lte-dual-sim-5.7-inch...
# 3     /xiaomi-redmi-9a-6.53-2gb-32gb-dual-sim-4g-lte...
# 4     /105-2019-1.77-dual-sim-fm-radio4mb-ram-fm-rad...
# ...                                                 ...
# 1921  /fast-android-cable-charger-oraimo-mpg302464.html
# 1922  /generic-clear-view-case-for-samsung-galaxy-a5...
# 1923  /generic-mini-wireless-bluetooth-4.0-stereo-in...
# 1924  /generic-sliding-camshield-case-for-nokia-c30-...
# 1925  /generic-4g-kids-smart-watch-global-positionin...
#
# [1926 rows x 4 columns]
